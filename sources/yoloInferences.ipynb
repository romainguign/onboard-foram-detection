# %%
from ultralytics import YOLO

model = YOLO("../Models/sharp_living/weights/best.pt")

# %%
model.predict(source="../data/images", save_crop=True, conf=0.5)
# Out:
# image 1/288 /home/roguigna/stage/keras/onboard-foram-detection/sources/../data/images/X08950_Y03500.png: 544x640 1 forams_all, 54.9ms
# image 2/288 /home/roguigna/stage/keras/onboard-foram-detection/sources/../data/images/X08950_Y03646.png: 544x640 1 forams_all, 6.7ms
# image 3/288 /home/roguigna/stage/keras/onboard-foram-detection/sources/../data/images/X08950_Y03792.png: 544x640 1 forams_all, 4.7ms
# image 4/288 /home/roguigna/stage/keras/onboard-foram-detection/sources/../data/images/X08950_Y03938.png: 544x640 (no detections), 5.6ms
# image 5/288 /home/roguigna/stage/keras/onboard-foram-detection/sources/../data/images/X08950_Y04084.png: 544x640 (no detections), 5.2ms
# image 6/288 /home/roguigna/stage/keras/onboard-foram-detection/sources/../data/images/X08950_Y04230.png: 544x640 (no detections), 4.9ms
# image 7/288 /home/roguigna/stage/keras/onboard-foram-detection/sources/../data/images/X08950_Y04376.png: 544x640 3 forams_alls, 4.6ms
# ...

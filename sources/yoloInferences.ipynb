# %%
from ultralytics import YOLO

model = YOLO("../Models/sharp_living/weights/best.pt")

# %%
model.predict(source="../data/images", save_txt=True, conf=0.5)
# Out:
# image 1/288 /home/roguigna/stage/keras/onboard-foram-detection/sources/../data/images/X08950_Y03500.png: 544x640 1 forams_all, 20.3ms
# image 2/288 /home/roguigna/stage/keras/onboard-foram-detection/sources/../data/images/X08950_Y03646.png: 544x640 1 forams_all, 20.4ms
# image 3/288 /home/roguigna/stage/keras/onboard-foram-detection/sources/../data/images/X08950_Y03792.png: 544x640 1 forams_all, 18.9ms
# image 4/288 /home/roguigna/stage/keras/onboard-foram-detection/sources/../data/images/X08950_Y03938.png: 544x640 (no detections), 18.7ms
# image 5/288 /home/roguigna/stage/keras/onboard-foram-detection/sources/../data/images/X08950_Y04084.png: 544x640 (no detections), 18.9ms
# image 6/288 /home/roguigna/stage/keras/onboard-foram-detection/sources/../data/images/X08950_Y04230.png: 544x640 (no detections), 18.8ms
# image 7/288 /home/roguigna/stage/keras/onboard-foram-detection/sources/../data/images/X08950_Y04376.png: 544x640 3 forams_alls, 18.7ms
# ...
